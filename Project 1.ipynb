# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __Furas Magrad__
#
# Computer Science

# %% [markdown]
# _I am interested in data science because i am very interested data. I believe working as a data scientist wont have a repetitive and boring day._

# %% [markdown]
# ### The following code finds the value of z.

# %%
x = 67
y = 21
z = x + y
print(z)
# Out:
# 88

# %% [markdown]
# - A
# - B
# - C
# - D
